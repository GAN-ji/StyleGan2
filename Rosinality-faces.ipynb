# %%
# !nvidia-smi
# Out:
# Fri May 20 08:27:51 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 465.19.01    CUDA Version: 11.3     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA Tesla V1...  On   | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    25W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/rosinality/stylegan2-pytorch.git ~/stylegan2-pytorch-faces
# Out:
# Cloning into '/home/aiffel9an/stylegan2-pytorch-faces'...
# remote: Enumerating objects: 395, done.
# remote: Total 395 (delta 0), reused 0 (delta 0), pack-reused 395
# Receiving objects: 100% (395/395), 122.51 MiB | 47.70 MiB/s, done.
# Resolving deltas: 100% (203/203), done.

# %%
# !pip install torch==1.8.1 torchvision==0.9.1
# !pip install ninja

# %%
pip install lmdb wandb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !unzip ~/data/images/data256-20220520T082938Z-001.zip -d ~/data/images/faces256
# Out:
# Archive:  /home/aiffel9an/data/images/data256-20220520T082938Z-001.zip
#   inflating: /home/aiffel9an/data/images/faces256/data256/smiling-face-with-rainbow-heart-eyes.png
#   inflating: /home/aiffel9an/data/images/faces256/data256/smiling-face-with-horns-and-halo.png
#   inflating: /home/aiffel9an/data/images/faces256/data256/silver_grinning-face-with-dizzy-goggles.png
#   inflating: /home/aiffel9an/data/images/faces256/data256/smiling-face-with-hearts-with-face-mask.png
#   inflating: /home/aiffel9an/data/images/faces256/data256/silver_smiling-face-with-hearts-with-face-mask.png
#   inflating: /home/aiffel9an/data/images/faces256/data256/slightly-smiling-face.png
#   inflating: /home/aiffel9an/data/images/faces256/data256/silver_worried-face-with-face-mask.png
#   inflating: /home/aiffel9an/data/images/faces256/data256/silver_tired-face.png
#   inflating: /home/aiffel9an/data/images/faces256/data256/silver_skeptical-smile-face.png
# ...

# %%
# !python ~/stylegan2-pytorch-faces/prepare_data.py --out ~/data/dataset/faces256lmdb --size 256 ~/data/images/faces256
# Out:
# Make dataset of image sizes: 256
# 0it [00:00, ?it/s]/home/aiffel9an/anaconda3/envs/rosinality/lib/python3.8/site-packages/torchvision/transforms/functional.py:364: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# /home/aiffel9an/anaconda3/envs/rosinality/lib/python3.8/site-packages/torchvision/transforms/functional.py:364: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# /home/aiffel9an/anaconda3/envs/rosinality/lib/python3.8/site-packages/torchvision/transforms/functional.py:364: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(
# ...

# %%
# !wandb login df712a0759dcf8a5795347db16956c6487d706ba
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /home/aiffel9an/.netrc

# %%
cd stylegan2-pytorch-faces
# Out:
# /home/aiffel9an/stylegan2-pytorch-faces

# %%
# !python train.py --augment --wandb --ckpt ~/550000.pt ~/data/dataset/faces256lmdb
# Out:
# load model: /home/aiffel9an/550000.pt
# wandb: Currently logged in as: paulcho98. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.16
# wandb: Run data is saved locally in /home/aiffel9an/stylegan2-pytorch-faces/wandb/run-20220520_083946-6dlnuy0v
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run winter-wind-20
# wandb: ⭐️ View project at https://wandb.ai/paulcho98/stylegan%202
# wandb: 🚀 View run at https://wandb.ai/paulcho98/stylegan%202/runs/6dlnuy0v
# d: 1.4942; g: 0.8229; r1: 0.0066; path: 0.0799; mean path: 0.0028; augment: 0.00/home/aiffel9an/anaconda3/envs/rosinality/lib/python3.8/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# d: 0.1367; g: 4.1249; r1: 0.0033; path: 0.0737; mean path: 0.0783; augment: 0.00wandb: Network error (ReadTimeout), entering retry loop.
# ...

# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
cd sample
# Out:
# /home/aiffel9an/stylegan2-pytorch-faces/sample

# %%
# !zip samples.zip ./*
# Out:
#   adding: 550000.png (deflated 0%)
#   adding: 550100.png (deflated 0%)
#   adding: 550200.png (deflated 0%)
#   adding: 550300.png (deflated 0%)
#   adding: 550400.png (deflated 0%)
#   adding: 550500.png (deflated 0%)
#   adding: 550600.png (deflated 0%)
#   adding: 550700.png (deflated 0%)
#   adding: 550800.png (deflated 0%)
#   adding: 550900.png (deflated 0%)
#   adding: 551000.png (deflated 0%)
#   adding: 551100.png (deflated 0%)
#   adding: 551200.png (deflated 0%)
#   adding: 551300.png (deflated 0%)
#   adding: 551400.png (deflated 0%)
#   adding: 551500.png (deflated 0%)
#   adding: 551600.png (deflated 0%)
#   adding: 551700.png (deflated 0%)
#   adding: 551800.png (deflated 0%)
#   adding: 551900.png (deflated 0%)
#   adding: 552000.png (deflated 0%)
#   adding: 552100.png (deflated 0%)
#   adding: 552200.png (deflated 0%)
#   adding: 552300.png (deflated 0%)
#   adding: 552400.png (deflated 0%)
#   adding: 552500.png (deflated 0%)
#   adding: 552600.png (deflated 0%)
# ...
