# %%
# !pip install -q cupy-cuda100
# !pip install -q futures
# !pip install -q chainer
# Out:
#      |████████████████████████████████| 58.9 MB 1.1 MB/s
# WARNING: Discarding https://files.pythonhosted.org/packages/55/db/97c1ca37edab586a1ae03d6892b6633d8eaa23b23ac40c7e5bbc55423c78/futures-3.0.5.tar.gz#sha256=0542525145d5afc984c88f914a0c85c77527f65946617edb5274f72406f981df (from https://pypi.org/simple/futures/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# WARNING: Discarding https://files.pythonhosted.org/packages/8d/73/b5fff618482bc06c9711e7cdc0d5d7eb1904d35898f48f2d7f9696b08bef/futures-3.0.4.tar.gz#sha256=19485d83f7bd2151c0aeaf88fbba3ee50dadfb222ffc3b66a344ef4952b782a3 (from https://pypi.org/simple/futures/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone -l -s https://github.com/tsurumeso/waifu2x-chainer.git waifu2x-chainer
# %cd waifu2x-chainer
# Out:
# Cloning into 'waifu2x-chainer'...
# ...
# remote: Enumerating objects: 1477, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 1477 (delta 0), reused 0 (delta 0), pack-reused 1474
# Receiving objects: 100% (1477/1477), 185.56 MiB | 18.77 MiB/s, done.
# Resolving deltas: 100% (833/833), done.
# /content/waifu2x-chainer

# %%
# 노트북에서 바로 업로드 가능.

# import google.colab.files
# %cd /content/drive/MyDrive/aiffel/GANji_project
# # %mkdir Input_images
# %mkdir data256
# %cd /content/drive/MyDrive/aiffel/GANji_project/all_128_png_mod
# uploaded = google.colab.files.upload()
# print(uploaded)

# %%
# %cd /content/drive/MyDrive/aiffel/GANji_project # 내 경로에 맞게 사용
# %mkdir flat512
# Out:
# /content/drive/MyDrive/aiffel/GANji_project

# %%
# %cd /content/waifu2x-chainer
# %pwd
# !python waifu2x.py -m scale -i /content/drive/MyDrive/data/gan/fulljpg/256 -o /content/drive/MyDrive/data/gan/fulljpg/512 -g 0 -s 2 -a 0 -n 1
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Elapsed time: 0.052335 sec
# Saved as '/content/drive/MyDrive/data/gan/fulljpg/512/construction-worker-dark-skin-tone_re.png'
# 2.0x scaling... OK
# Elapsed time: 0.052974 sec
# Saved as '/content/drive/MyDrive/data/gan/fulljpg/512/couple-with-heart-medium-dark-skin-tone_re.png'
# 2.0x scaling... OK
# Elapsed time: 0.052341 sec
# Saved as '/content/drive/MyDrive/data/gan/fulljpg/512/horse-racing-medium-dark-skin-tone_re.png'
# 2.0x scaling... OK
# Elapsed time: 0.051867 sec
# Saved as '/content/drive/MyDrive/data/gan/fulljpg/512/mage-dark-skin-tone_re.png'
# 2.0x scaling... OK
# Elapsed time: 0.054805 sec
# Saved as '/content/drive/MyDrive/data/gan/fulljpg/512/man-biking-medium-skin-tone_re.png'
# 2.0x scaling... OK
# Elapsed time: 0.052142 sec
# Saved as '/content/drive/MyDrive/data/gan/fulljpg/512/deaf-man-light-skin-tone_re.png'
# 2.0x scaling... OK
# Elapsed time: 0.054006 sec
# ...

# %%
# !nvcc --version
# !pip install cupy-cuda100

# %%
# !zip -r /content/output.zip /content/Output_images
